# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import RepeatedKFold, cross_val_score
from sklearn.svm import SVC
from sklearn.datasets import load_digits
# Load dataset
digits = load_digits()

X = digits.data
y = digits.target

print("Feature Shape:", X.shape)
print("Target Shape:", y.shape)
# Create SVM classifier
model = SVC(kernel='rbf')
# Repeated K-Fold
rkf = RepeatedKFold(
    n_splits=5,
    n_repeats=3,
    random_state=42
)
scores = cross_val_score(
    model,
    X,
    y,
    cv=rkf,
    scoring='accuracy'
)

print("Accuracy Scores:", scores)
print("Average Accuracy:", scores.mean())
import matplotlib.pyplot as plt

plt.imshow(digits.images[0], cmap="gray")
plt.title("Example Digit")
plt.show()
# Out:
# Feature Shape: (1797, 64)
# Target Shape: (1797,)
# Accuracy Scores: [0.98611111 0.98888889 0.98607242 0.98885794 0.98885794 0.98611111
#  0.98611111 0.98050139 0.98607242 0.99442897 0.98888889 0.98333333
#  0.98328691 0.98885794 0.99164345]
# Average Accuracy: 0.9872015887754048
